# %%
import data_setup as ds
import numpy as np
import IPython.display as ipd
import random

# %%
df = ds.text_preprocessing("../text_transcription/metadata.csv")

rand_int = random.randint(0, len(df))
print(df.iloc[rand_int]["Transcription"])
ipd.Audio(data=df.iloc[rand_int]["wav_array"], autoplay=True, rate=22000)
# Out:
# those who could not pay were thrown into the wards with the night charges
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
